# %% [markdown]
# # Limitless Data Extraction

# %%
import requests
import bs4 as bs4

# %% [markdown]
# ## Environment Variables

# %%
set_list = []
BASE_URL = "https://pocket.limitlesstcg.com"
card_list = []

# %% [markdown]
# ## Extracting Sets URLs

# %%
response = requests.get(f"{BASE_URL}/cards")
if response.status_code == 200:
    content = bs4.BeautifulSoup(response.content, "html.parser")

    table = content.find("table", {"class": "sets-table"})
    sets = table.find_all("a")

    for set in sets:
        url = f"{BASE_URL}{set.get("href")}"
        if url not in set_list:
          set_list.append(url)
else:
    print(f"Failed to retrieve sets data from {BASE_URL}. Status code: {response.status_code}")
    exit(1)

# %% [markdown]
# ## Extracting Cards from Sets

# %%
for url in set_list:
    response = requests.get(url)
    if response.status_code == 200:
        content = bs4.BeautifulSoup(response.content, "html.parser")
        grid = content.find("div", {"class": "card-search-grid"})
        cards = grid.find_all("a")

        for row in cards:
            url_card = f"{BASE_URL}{row.get('href')}"
            img = row.img.get("src")
            card_list.append({"set": url, "img": img, "card": url_card})
            
        print(f"Retrieved {len(cards)} cards from {url}")
        
    else:
        print(f"Failed to retrieve cards data from set {url}. Status code: {response.status_code}")
# Out:
# Retrieved 103 cards from https://pocket.limitlesstcg.com/cards/A3a
# Retrieved 239 cards from https://pocket.limitlesstcg.com/cards/A3
# Retrieved 111 cards from https://pocket.limitlesstcg.com/cards/A2b
# Retrieved 96 cards from https://pocket.limitlesstcg.com/cards/A2a
# Retrieved 207 cards from https://pocket.limitlesstcg.com/cards/A2
# Retrieved 86 cards from https://pocket.limitlesstcg.com/cards/A1a
# Retrieved 286 cards from https://pocket.limitlesstcg.com/cards/A1
# Retrieved 83 cards from https://pocket.limitlesstcg.com/cards/P-A

# %% [markdown]
# ## Extracting Cards Details

# %%
for item in card_list:
    content = requests.get(item["card"])
    card_page = bs4.BeautifulSoup(content.content, "html.parser")
    card = card_page.find("div", {"class": "card-details-main"})
    name_type_hp = card.find("p", {"class": "card-text-title"})
    print(f"Card: {name_type_hp.text.split('-')}")
# Out:
# Card: ['\nPetilil\n              ', ' Grass               ', ' 60 HP         ']
# Card: ['\nLilligant\n              ', ' Grass               ', ' 110 HP         ']
# Card: ['\nRowlet\n              ', ' Grass               ', ' 60 HP         ']
# Card: ['\nDartrix\n              ', ' Grass               ', ' 80 HP         ']
# Card: ['\nDecidueye\n              ', ' Grass               ', ' 130 HP         ']
# Card: ['\nBuzzwole ex\n              ', ' Grass               ', ' 140 HP         ']
# Card: ['\nPheromosa\n              ', ' Grass               ', ' 70 HP         ']
# Card: ['\nKartana\n              ', ' Grass               ', ' 60 HP         ']
# Card: ['\nBlacephalon\n              ', ' Fire               ', ' 100 HP         ']
# Card: ['\nMantine\n              ', ' Water               ', ' 90 HP         ']
# Card: ['\nCarvanha\n              ', ' Water               ', ' 60 HP         ']
# ...
